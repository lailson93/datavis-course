# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
dados = pd.read_csv('cape_exterior.csv')

# print(dados.head())
dados.columns
# Out:
# Index(['Unnamed: 0', 'index', 'ARTICULADOR PEDAGÓGICO', 'Ano',
#        'CAPACITAÇÃO PROFESSORES DA EDUCAÇÃO BÁSICA', 'CÁTEDRA',
#        'DOUTORADO PLENO', 'DOUTORADO SANDUÍCHE', 'Doutorado',
#        'Doutorado Sanduíche', 'ESCOLA DE ALTOS ESTUDOS', 'ESPECIALIZAÇÃO',
#        'ESTÁGIO DOCENTE', 'ESTÁGIO SÊNIOR', 'Especialização', 'Estágio Sênior',
#        'GRADUAÇÃO', 'GRADUAÇÃO PLENA', 'GRADUAÇÃO SANDUÍCHE',
#        'Graduação Sanduíche', 'MESTRADO', 'MESTRADO PROFISSIONAL',
#        'MESTRADO SANDUÍCHE', 'Mestrado', 'Mestrado Sanduíche', 'PIDRH',
#        'PROFESSOR/PESQUISADOR VISITANTE', 'País',
#        'Professor de Educação Básica', 'PÓS-DOUTORADO', 'Pós Doc',
#        'Total Linha'],
#       dtype='object')

# %%
bolsas_byYear = dados.groupby(['Ano']).sum()
bolsas_byYear
# Out:
#       Unnamed: 0  index  ARTICULADOR PEDAGÓGICO  \
# Ano
# 1998         406    406                     0.0
# 1999        1134    351                     0.0
# 2000        1781    325                     0.0
# 2001        2565    351                     0.0
# 2002        3567    406                     0.0
# 2003        4077    351                     0.0
# 2004        5385    435                     0.0
# 2005        7191    561                     0.0
# 2006        9940    780                     0.0
# 2007       11849    820                     0.0
# 2008       14586    946                     0.0
# 2009       14940    780                     0.0
# 2010       16540    780                     0.0
# 2011       20042    946                     0.0
# 2012       24072   1128                     0.0
# 2013       29256   1378                     5.0
# 2014       34599   1596                     4.0
# 2015       38541   1653                     0.0
# 2016       35925   1225                     0.0
# 2017       51249   2145                     0.0
# 2018       50370   1770                     0.0
#
#       CAPACITAÇÃO PROFESSORES DA EDUCAÇÃO BÁSICA  CÁTEDRA  DOUTORADO PLENO  \
# Ano
# 1998                                         0.0      0.0              0.0
# 1999                                         0.0      0.0              0.0
# 2000                                         0.0      0.0              0.0
# 2001                                         0.0      0.0              0.0
# 2002                                         0.0      0.0              0.0
# 2003                                         0.0      0.0              0.0
# 2004                                         0.0      0.0              0.0
# 2005                                         0.0      0.0              0.0
# 2006                                         0.0      0.0              0.0
# 2007                                         0.0      0.0              0.0
# 2008                                         0.0      0.0              0.0
# 2009                                         0.0      0.0              0.0
# 2010                                         0.0      0.0              0.0
# 2011                                         0.0      0.0              0.0
# 2012                                         0.0      0.0              0.0
# 2013                                      1106.0      7.0           1301.0
# 2014                                        82.0      8.0           2243.0
# 2015                                        35.0      6.0           2492.0
# 2016                                        73.0     14.0           2219.0
# 2017                                        74.0      8.0           1975.0
# 2018                                         0.0      8.0           1322.0
#
#       DOUTORADO SANDUÍCHE  Doutorado  Doutorado Sanduíche  \
# Ano
# 1998                  0.0     1088.0                392.0
# 1999                  0.0     1088.0                499.0
# 2000                  0.0     1012.0                661.0
# 2001                  0.0      931.0                710.0
# 2002                  0.0      893.0                836.0
# 2003                  0.0      966.0                962.0
# 2004                  0.0      939.0               1013.0
# 2005                  0.0      943.0               1296.0
# 2006                           0.0            0.0    757.0         3863
# 2007                           0.0            0.0    829.0         3906
# 2008                           0.0            0.0    922.0         3972
# 2009                           0.0            0.0    841.0         4159
# 2010                           0.0            0.0    729.0         4902
# 2011                           0.0            0.0    853.0         6361
# 2012                         645.0            0.0    921.0        11983
# 2013                           0.0         1092.0      0.0        26219
# 2014                           0.0         1382.0      0.0        44412
# 2015                           0.0         1246.0      0.0        40325
# 2016                           0.0          639.0      0.0        16901
# 2017                           0.0          451.0      0.0         9563
# 2018                           0.0          495.0      0.0         8156
#
# [21 rows x 30 columns]

# %%
serie_bolsas = bolsas_byYear[['ARTICULADOR PEDAGÓGICO','CAPACITAÇÃO PROFESSORES DA EDUCAÇÃO BÁSICA', 'CÁTEDRA','DOUTORADO PLENO', 'DOUTORADO SANDUÍCHE', 'Doutorado','Doutorado Sanduíche', 'ESCOLA DE ALTOS ESTUDOS', 'ESPECIALIZAÇÃO','ESTÁGIO DOCENTE', 'ESTÁGIO SÊNIOR', 'Especialização', 'Estágio Sênior','GRADUAÇÃO', 'GRADUAÇÃO PLENA', 'GRADUAÇÃO SANDUÍCHE','Graduação Sanduíche', 'MESTRADO', 'MESTRADO PROFISSIONAL','MESTRADO SANDUÍCHE', 'Mestrado', 'Mestrado Sanduíche', 'PIDRH','PROFESSOR/PESQUISADOR VISITANTE','Professor de Educação Básica', 'PÓS-DOUTORADO', 'Pós Doc']]

# %%
# export_csv = teste.to_csv (r'export_dataframe_extrangeiro.csv', index = None, header=True)

# %%
type(serie_bolsas)
# Out:
# pandas.core.frame.DataFrame

# %%
series_extras = serie_bolsas['ARTICULADOR PEDAGÓGICO']
type(series_extras)
# series_extras
# Out:
# pandas.core.series.Series

# %%
# doutorado = (serie_bolsas['Doutorado']+serie_bolsas['DOUTORADO PLENO']+serie_bolsas['DOUTORADO SANDUÍCHE'] + serie_bolsas['Doutorado Sanduíche']).to_frame()
# graduacao = (serie_bolsas['GRADUAÇÃO SANDUÍCHE'] + serie_bolsas['Graduação Sanduíche'] + serie_bolsas['GRADUAÇÃO']+serie_bolsas['GRADUAÇÃO PLENA']).to_frame()
# mestrado = (serie_bolsas['MESTRADO PROFISSIONAL']+serie_bolsas['MESTRADO']+serie_bolsas['Mestrado']+serie_bolsas['MESTRADO SANDUÍCHE']+serie_bolsas['Mestrado Sanduíche']).to_frame()
# pos_doc = (serie_bolsas['PÓS-DOUTORADO'] + serie_bolsas['Pós Doc']).to_frame()

# %%
doutorado = (serie_bolsas['Doutorado']+serie_bolsas['DOUTORADO PLENO']+serie_bolsas['DOUTORADO SANDUÍCHE'] + serie_bolsas['Doutorado Sanduíche'])
graduacao = (serie_bolsas['GRADUAÇÃO SANDUÍCHE'] + serie_bolsas['Graduação Sanduíche'] + serie_bolsas['GRADUAÇÃO']+serie_bolsas['GRADUAÇÃO PLENA'])
mestrado = (serie_bolsas['MESTRADO PROFISSIONAL']+serie_bolsas['MESTRADO']+serie_bolsas['Mestrado']+serie_bolsas['MESTRADO SANDUÍCHE']+serie_bolsas['Mestrado Sanduíche'])
pos_doc = (serie_bolsas['PÓS-DOUTORADO'] + serie_bolsas['Pós Doc'])

df = pd.DataFrame()
df['GRADUACAO'] = graduacao
df['DOUTORADO'] = doutorado
df['MESTRADO'] = mestrado
df['POS_DOC'] = pos_doc
df['ARTICULADOR PEDAGÓGICO'] = serie_bolsas['ARTICULADOR PEDAGÓGICO']
df['CAPACITAÇÃO PROFESSORES DA EDUCAÇÃO BÁSICA'] = serie_bolsas['CAPACITAÇÃO PROFESSORES DA EDUCAÇÃO BÁSICA']
df['CÁTEDRA'] = serie_bolsas['CÁTEDRA']
df['PIDRH'] = serie_bolsas['PIDRH']
df['PROFESSOR/PESQUISADOR VISITANTE'] = serie_bolsas['PROFESSOR/PESQUISADOR VISITANTE']
df['Professor de Educação Básica'] = serie_bolsas['Professor de Educação Básica']
df_transportada = df.transpose()
df_transportada
# Out:
# Ano                                           1998    1999    2000    2001  \
# GRADUACAO                                    103.0   344.0   470.0   418.0
# DOUTORADO                                   1480.0  1587.0  1673.0  1641.0
# MESTRADO                                      18.0    10.0    20.0    26.0
# POS_DOC                                      266.0   256.0   267.0   407.0
# ARTICULADOR PEDAGÓGICO                         0.0     0.0     0.0     0.0
# CAPACITAÇÃO PROFESSORES DA EDUCAÇÃO BÁSICA     0.0     0.0     0.0     0.0
# CÁTEDRA                                        0.0     0.0     0.0     0.0
# PIDRH                                          0.0     0.0     0.0     0.0
# PROFESSOR/PESQUISADOR VISITANTE                0.0     0.0     0.0     0.0
# Professor de Educação Básica                   0.0     0.0     0.0     0.0
#
# Ano                                           2002    2003    2004    2005  \
# GRADUACAO                                    268.0   253.0   422.0   622.0
# DOUTORADO                                   1729.0  1928.0  1952.0  2239.0
# MESTRADO                                      19.0     7.0    10.0     7.0
# POS_DOC                                      454.0   454.0   535.0   639.0
# ARTICULADOR PEDAGÓGICO                         0.0     0.0     0.0     0.0
# CAPACITAÇÃO PROFESSORES DA EDUCAÇÃO BÁSICA     0.0     0.0     0.0     0.0
# CÁTEDRA                                        0.0     0.0     0.0     0.0
# PIDRH                                          0.0     0.0     0.0     0.0
# PROFESSOR/PESQUISADOR VISITANTE                0.0     0.0     0.0     0.0
# Professor de Educação Básica                   0.0     0.0     0.0     0.0
#
# Ano                                           2006    2007  ...    2009  \
# GRADUACAO                                    648.0   676.0  ...   891.0
# DOUTORADO                                   2451.0  2394.0  ...  2331.0
# MESTRADO                                       7.0     7.0  ...    17.0
# POS_DOC                                      757.0   829.0  ...   841.0
# ARTICULADOR PEDAGÓGICO                         0.0     0.0  ...     0.0
# CAPACITAÇÃO PROFESSORES DA EDUCAÇÃO BÁSICA     0.0     0.0  ...     0.0
# CÁTEDRA                                        0.0     0.0  ...     0.0
# PIDRH                                          0.0     0.0  ...     0.0
# PROFESSOR/PESQUISADOR VISITANTE                0.0     0.0  ...     0.0
# Professor de Educação Básica                   0.0     0.0  ...     0.0
#
# Ano                                           2010    2011    2012     2013  \
# GRADUACAO                                   1473.0  2446.0  6190.0  17972.0
# DOUTORADO                                   2467.0  2822.0  3847.0   5250.0
# MESTRADO                                      29.0    56.0    99.0     96.0
# POS_DOC                                      729.0   853.0   921.0   1092.0
# ARTICULADOR PEDAGÓGICO                         0.0     0.0     0.0      5.0
# CAPACITAÇÃO PROFESSORES DA EDUCAÇÃO BÁSICA     0.0     0.0     0.0   1106.0
# CÁTEDRA                                        0.0     0.0     0.0      7.0
# PIDRH                                          0.0     0.0     0.0      0.0
# PROFESSOR/PESQUISADOR VISITANTE                0.0     0.0     0.0      0.0
# Professor de Educação Básica                   0.0     0.0   645.0      0.0
#
# Ano                                            2014     2015     2016    2017  \
# GRADUACAO                                   33991.0  29579.0  10593.0  1668.0
# DOUTORADO                                    7354.0   7728.0   4470.0  6955.0
# MESTRADO                                      637.0    611.0    478.0    35.0
# POS_DOC                                      1382.0   1246.0    639.0   451.0
# ARTICULADOR PEDAGÓGICO                          4.0      0.0      0.0     0.0
# CAPACITAÇÃO PROFESSORES DA EDUCAÇÃO BÁSICA     82.0     35.0     73.0    74.0
# CÁTEDRA                                         8.0      6.0     14.0     8.0
# PIDRH                                           0.0      0.0      2.0     0.0
# PROFESSOR/PESQUISADOR VISITANTE                22.0     11.0      0.0     1.0
# Professor de Educação Básica                    0.0      0.0      0.0     0.0
#
# Ano                                           2018
# GRADUACAO                                   1687.0
# DOUTORADO                                   5504.0
# MESTRADO                                      23.0
# POS_DOC                                      495.0
# ARTICULADOR PEDAGÓGICO                         0.0
# CAPACITAÇÃO PROFESSORES DA EDUCAÇÃO BÁSICA     0.0
# CÁTEDRA                                        8.0
# PIDRH                                          0.0
# PROFESSOR/PESQUISADOR VISITANTE              415.0
# Professor de Educação Básica                   0.0
#
# [10 rows x 21 columns]

# %%
export_csv = df_transportada.to_csv (r'extrangeiro_transport.csv', header=True)

# %%
# Out:
#         Tipo                                         Quantidade
# 0  doutorado             0
# Ano
# 1998  1480.0
# 1999  1...
# 1  graduacao              0
# Ano
# 1998    103.0
# 1999...
# 2   mestrado            0
# Ano
# 1998   18.0
# 1999   10....
# 3    pos_doc             0
# Ano
# 1998   266.0
# 1999   ...

# %%
serie_bolsas = teste.sum(skipna = True)

# %%
serie_bolsas[['ARTICULADOR PEDAGÓGICO','CAPACITAÇÃO PROFESSORES DA EDUCAÇÃO BÁSICA', 'CÁTEDRA','DOUTORADO PLENO', 'Doutorado', 'ESCOLA DE ALTOS ESTUDOS', 'ESPECIALIZAÇÃO','ESTÁGIO DOCENTE', 'ESTÁGIO SÊNIOR', 'Especialização', 'Estágio Sênior','GRADUAÇÃO', 'GRADUAÇÃO PLENA','MESTRADO PROFISSIONAL', 'PIDRH','PROFESSOR/PESQUISADOR VISITANTE','Professor de Educação Básica']]
# Out:
# ARTICULADOR PEDAGÓGICO                            9.0
# CAPACITAÇÃO PROFESSORES DA EDUCAÇÃO BÁSICA     1370.0
# CÁTEDRA                                          51.0
# DOUTORADO PLENO                               11552.0
# Doutorado                                     12780.0
# ESCOLA DE ALTOS ESTUDOS                           1.0
# ESPECIALIZAÇÃO                                  719.0
# ESTÁGIO DOCENTE                                 417.0
# ESTÁGIO SÊNIOR                                 2622.0
# Especialização                                   68.0
# Estágio Sênior                                  680.0
# GRADUAÇÃO                                         1.0
# GRADUAÇÃO PLENA                                   2.0
# MESTRADO PROFISSIONAL                          1612.0
# PIDRH                                             2.0
# PROFESSOR/PESQUISADOR VISITANTE                 449.0
# Professor de Educação Básica                    645.0
# dtype: float64

# %%
data = [['doutorado',doutorado],['graduacao',graduacao],['mestrado',mestrado],['pos_doc',pos_doc]]
df = pd.DataFrame(data, columns = ['Tipo', 'Quantidade'])

# %%
df
# Out:
#         Tipo  Quantidade
# 0  doutorado     70065.0
# 1  graduacao    111501.0
# 2   mestrado      2212.0
# 3    pos_doc     14435.0
